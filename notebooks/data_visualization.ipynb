# %%
# In this notebook we experiment with keras ImageDataGenerator to load our data in batches
#  and increase the size of our dataset by augmenting the images
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
def image_visualizer(generator):
    # get classes
    label_map = {v: k for k, v in generator.class_indices.items()}

    # visualize a few images
    i = 0
    data = next(train_generator)
    print("We receive a batch of 32 256x256x3 images", data[0].shape, data[1].shape)
    while i < 5:
        print(label_map[np.argmax(data[1][i])])
        plt.imshow(data[0][i])
        plt.show()
        i += 1

# %%
datagen = ImageDataGenerator(rescale=1./255)
# using defaults from this function will return shuffled images in batches of 32, resized to 256x256
image_visualizer(datagen.flow_from_directory('../data/'))
# Out:
# Found 6108 images belonging to 41 classes.
# We receive a batch of 32 256x256x3 images (32, 256, 256, 3) (32, 43)
# AmbassadorTheatre
# NederlanderTheatre
# NewAmsterdamTheatre
# MinskoffTheatre
# ImperialTheatre

# %%
# visualize augmented data
train_datagen = ImageDataGenerator(rescale=1./255, zoom_range=0.3, rotation_range=50,
                                   width_shift_range=0.2, height_shift_range=0.2, shear_range=0.2, 
                                   horizontal_flip=True, fill_mode='nearest', brightness_range=[0.5, 1.5])
image_visualizer(train_datagen.flow_from_directory('../data/'))
# Out:
# Found 6108 images belonging to 41 classes.
# We receive a batch of 32 256x256x3 images (32, 256, 256, 3) (32, 43)
# CircleintheSquareTheatre
# ImperialTheatre
# NederlanderTheatre
# JohnGoldenTheatre
# BelascoTheatre
